# %% [markdown]
# <a href="https://colab.research.google.com/github/aruntahilramani/134_ArunTahilramani/blob/master/Lab3/134_Ex3_NB_Classifier_Iris_3Classes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example

# %%
#Import scikit-learn dataset library
from sklearn import datasets
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report

# %%
iris = datasets.load_iris()
# print the names of the 13 features
print("Features: ", iris.feature_names)

# print the label type of wine(class_0, class_1, class_2)
print("Labels: ", iris.target_names)

# print data(feature)shape
iris.data.shape
# Out:
# Features:  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Labels:  ['setosa' 'versicolor' 'virginica']
# (150, 4)

# %%
#import the necessary module
from sklearn.model_selection import train_test_split

#split data set into train and test sets
data_train, data_test, target_train, target_test = train_test_split(iris.data,
                        iris.target, test_size = 0.30, random_state = 10)

# %%
import numpy as np
gnb = GaussianNB()

#Train the model using the training sets
gnb.fit(data_train, target_train)

#Predict the response for test dataset
target_pred = gnb.predict(data_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(target_test, target_pred))
# Out:
# Accuracy: 1.0

# %%
#Import confusion_matrix from scikit-learn metrics module for confusion_matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(target_test, target_pred)
# Out:
# array([[14,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  0, 14]])

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

precision = precision_score(target_test, target_pred, average=None)
recall = recall_score(target_test, target_pred, average=None)

print('precision: {}'.format(precision))
print('recall: {}'.format(recall))
# Out:
# precision: [1. 1. 1.]
# recall: [1. 1. 1.]

# %% [markdown]
# **Exercise:**
#
#
# **6) 126<=Rollnumber + All with No RollNumbers:**
#   #Task 1: Try the algo on Dataset3 - LabelEncoding of features:and Train test Division 95%-5%
#
#  #Task 2: Apply algorithm on breast cancer wisconsin dataset - One Hot Encoding of features: and Train test Division 50%-50%
#
#
#
# **Instruction for Task-1 & 2:**
#
# i) Set Random state of model equals to your roll number (or last 2 digit of your id -if you don't have roll number)
#
#
# **Questions: For Task - 1**
#
# (1) What will be the value of Play, if Outlook is ’Rainy’, Temperature is ’Mild’, Humidity =’Normal’, and Wind = ’False’?
#
# (2) What will be the value of Play, if Outlook is ’Sunny’, Temeprature is ’Cool’, Humidity =’High’, and Wind = ’True’?
#
# (3) Accuracy , precision and recall of both Models?

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn import metrics
from sklearn import datasets
import matplotlib.pyplot as plt

# %% [markdown]
# # Task -1

# %%
dataset3 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ML/Lab3/PracticeDataSets/Dataset3.csv")

# %%
dataset3.head()
# Out:
#   Outlook Temp Wind  Humidity  Class
# 0       R    H    F         1      0
# 1       R    H    T         2      0
# 2       O    H    F         1      1
# 3       R    M    F         1      1
# 4       S    C    F         1      1

# %%
Data3,Label3 = dataset3.loc[:,dataset3.columns != 'Class'],dataset3.loc[:,'Class']

# %%
data_train3, data_test3, target_train3, target_test3 =\
train_test_split(Data3,Label3, test_size = 0.05, random_state = 134)

# %%
data_train3 = data_train3.apply(preprocessing.LabelEncoder().fit_transform)

# %%
gnb = GaussianNB()

#Train the model using the training sets
gnb.fit(data_train3, target_train3)

#Predict the response for test dataset
data_test3 = data_test3.apply(preprocessing.LabelEncoder().fit_transform)
target_pred3 = gnb.predict(data_test3)

# %%
print(metrics.classification_report(target_test3, target_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         1
#
#     accuracy                           1.00         1
#    macro avg       1.00      1.00      1.00         1
# weighted avg       1.00      1.00      1.00         1

# %%
gnb.predict([[1,2,1,0],[2,0,0,1]])
# Out:
# array([0, 1])

# %% [markdown]
# # Task - 2

# %%
cancer_data = datasets.load_breast_cancer()
# print the names of the 13 features
print("Features: ", cancer_data.feature_names)

# print the label type of wine(class_0, class_1, class_2)
print("Labels: ", cancer_data.target_names)

# print data(feature)shape
cancer_data.data.shape
# Out:
# Features:  ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']
# Labels:  ['malignant' 'benign']
# (569, 30)

# %%
#print(cancer_data.DESCR)
cancer_data.data[:3]
# Out:
# array([[1.799e+01, 1.038e+01, 1.228e+02, 1.001e+03, 1.184e-01, 2.776e-01,
#         3.001e-01, 1.471e-01, 2.419e-01, 7.871e-02, 1.095e+00, 9.053e-01,
#         8.589e+00, 1.534e+02, 6.399e-03, 4.904e-02, 5.373e-02, 1.587e-02,
#         3.003e-02, 6.193e-03, 2.538e+01, 1.733e+01, 1.846e+02, 2.019e+03,
#         1.622e-01, 6.656e-01, 7.119e-01, 2.654e-01, 4.601e-01, 1.189e-01],
#        [2.057e+01, 1.777e+01, 1.329e+02, 1.326e+03, 8.474e-02, 7.864e-02,
#         8.690e-02, 7.017e-02, 1.812e-01, 5.667e-02, 5.435e-01, 7.339e-01,
#         3.398e+00, 7.408e+01, 5.225e-03, 1.308e-02, 1.860e-02, 1.340e-02,
#         1.389e-02, 3.532e-03, 2.499e+01, 2.341e+01, 1.588e+02, 1.956e+03,
#         1.238e-01, 1.866e-01, 2.416e-01, 1.860e-01, 2.750e-01, 8.902e-02],
#        [1.969e+01, 2.125e+01, 1.300e+02, 1.203e+03, 1.096e-01, 1.599e-01,
#         1.974e-01, 1.279e-01, 2.069e-01, 5.999e-02, 7.456e-01, 7.869e-01,
#         4.585e+00, 9.403e+01, 6.150e-03, 4.006e-02, 3.832e-02, 2.058e-02,
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder(handle_unknown='ignore')
enc.fit(cancer_data.data)
nColumns=0
for i in range(len(cancer_data.feature_names)):
    nColumns+=len(enc.categories_[i])
print("total columns after one hot encoding: ",nColumns)
print("approximate size : ",15340*569*1/(10**6)," mb")
# Out:
# total columns after one hot encoding:  15340
# approximate size :  8.72846  mb

# %% [markdown]
# ## here you can see all 30 colums has datatype as double and have wide range of values so onehot encoding shouldn't be applied

# %%
N=len(cancer_data.feature_names)
plt.figure(figsize=(25,60))
for i in range(N):
    plt.subplot(10,3,i+1)
    plt.xlabel(cancer_data.feature_names[i],{'fontname':'sans-serif'})
    plt.hist(x=cancer_data.data[i],bins=60)

# %%
data_train, data_test, target_train, target_test = train_test_split(cancer_data.data,
                        cancer_data.target, test_size = 0.50, random_state = 134)

# %%
mnb=MultinomialNB()
mnb.fit(data_train,target_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
target_pred=mnb.predict(data_test)

# %%
print(classification_report(target_test,target_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87       100
#            1       0.91      0.96      0.93       185
#
#     accuracy                           0.91       285
#    macro avg       0.91      0.89      0.90       285
# weighted avg       0.91      0.91      0.91       285
